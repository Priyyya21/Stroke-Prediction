# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"healthcare-dataset-stroke-data.csv")

# %%
df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df['bmi'].fillna(int(df['bmi'].mean()),inplace = True)
df.isnull().sum()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_23112\622062109.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(int(df['bmi'].mean()),inplace = True)
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df2 = df.drop('id',axis=1)
df2.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21  28.0     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# # ENCODING

# %%
categorical_cols = ['gender','ever_married','work_type','Residence_type','smoking_status']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()
df2[categorical_cols] = oe.fit_transform(df2[categorical_cols])

# %%
df2
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0        1.0  67.0             0              1           1.0        2.0
# 1        0.0  61.0             0              0           1.0        3.0
# 2        1.0  80.0             0              1           1.0        2.0
# 3        0.0  49.0             0              0           1.0        2.0
# 4        0.0  79.0             1              0           1.0        3.0
# ...      ...   ...           ...            ...           ...        ...
# 5105     0.0  80.0             1              0           1.0        2.0
# 5106     0.0  81.0             0              0           1.0        3.0
# 5107     0.0  35.0             0              0           1.0        3.0
# 5108     1.0  51.0             0              0           1.0        2.0
# 5109     0.0  44.0             0              0           1.0        0.0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                1.0             228.69  36.6             1.0       1
# 1                0.0             202.21  28.0             2.0       1
# 2                0.0             105.92  32.5             2.0       1
# 3                1.0             171.23  34.4             3.0       1
# 4                0.0             174.12  24.0             2.0       1
# ...              ...                ...   ...             ...     ...
# 5105             1.0              83.75  28.0             2.0       0
# 5106             1.0             125.20  40.0             2.0       0
# 5107             0.0              82.99  30.6             2.0       0
# 5108             0.0             166.29  25.6             1.0       0
# 5109             1.0              85.28  26.2             0.0       0
#
# [5110 rows x 11 columns]

# %%
df2[categorical_cols] = df2[categorical_cols].astype(int)

# %%
df2.dtypes
# Out:
# gender                 int64
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married           int64
# work_type              int64
# Residence_type         int64
# avg_glucose_level    float64
# bmi                  float64
# smoking_status         int64
# stroke                 int64
# dtype: object

# %%
df2['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# %%
df_major = df2[(df2['stroke']==0)]
df_minor = df2[(df2['stroke']==1)]
df_minor_resmapled = resample(df_minor,replace=True,n_samples=4861,random_state=42)
df_resampled = pd.concat([df_minor_resmapled,df_major])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='stroke', data=df_resampled)
plt.title('Distribution of Stroke Cases')
plt.xlabel('Stroke (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %%
sns.heatmap(df_resampled.corr(), fmt='.2g')
# Out:
# <Axes: >

# %%
x = df_resampled.iloc[:,:-1]
y = df_resampled['stroke']

# %%
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict
from sklearn.metrics import accuracy_score
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=7)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy Score :",round(dtc.score(x_test,y_test)*100,2),"%")
# Out:
# Accuracy Score : 97.12 %

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print("Accuracy Score :",round(xgb.score(x_test,y_test)*100,2),"%")
# Out:
# Accuracy Score : 97.07 %

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print("Accuracy Score :",round(rfc.score(x_test,y_test)*100,2),"%")
# Out:
# Accuracy Score : 99.02 %

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\priya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Accuracy Score :",round(lr.score(x_test,y_test)*100,2),"%")
# Out:
# Accuracy Score : 76.61 %

# %%
#importing classification report and confusion Matrix
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # XGBoost

# %%
y_pred = xgb.predict(x_test)
print("Classification Report", classification_report(y_test,y_pred))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       988
#            1       0.94      1.00      0.97       957
#
#     accuracy                           0.97      1945
#    macro avg       0.97      0.97      0.97      1945
# weighted avg       0.97      0.97      0.97      1945

# %%
cm = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(5,5))
sns.heatmap(data=cm,linewidths=.5,annot=True,square=True,cmap='Blues')
plt.xlabel("Predicted label")
plt.ylabel("Actual label")
sample_title = 'Accuracy Score: {0}'.format(xgb.score(x_test,y_test))
plt.title(sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.970694087403599')

# %%
model = XGBClassifier(eval_metric=['error','logloss'])
eval_set = [(x_train,y_train),(x_test,y_test)]
model.fit(x_train,y_train,eval_set=eval_set,verbose=True)
results = model.evals_result()
epochs = len(results['validation_0']['error'])
x_axis = range(0,epochs)
# plot Log Loss
fig,ax = plt.subplots()
ax.plot(x_axis,results['validation_0']['logloss'],label = 'Train')
ax.plot(x_axis,results['validation_1']['logloss'],label = 'Test')
ax.legend()
plt.ylabel('Log Loss')
plt.show()
# Out:
# [0]	validation_0-error:0.16703	validation_0-logloss:0.56057	validation_1-error:0.17481	validation_1-logloss:0.56337
# [1]	validation_0-error:0.13720	validation_0-logloss:0.47580	validation_1-error:0.15784	validation_1-logloss:0.48586
# [2]	validation_0-error:0.12408	validation_0-logloss:0.41824	validation_1-error:0.14190	validation_1-logloss:0.43022
# [3]	validation_0-error:0.11328	validation_0-logloss:0.38150	validation_1-error:0.13265	validation_1-logloss:0.39625
# [4]	validation_0-error:0.10390	validation_0-logloss:0.35381	validation_1-error:0.12596	validation_1-logloss:0.36730
# [5]	validation_0-error:0.10197	validation_0-logloss:0.33516	validation_1-error:0.12082	validation_1-logloss:0.35037
# [6]	validation_0-error:0.09798	validation_0-logloss:0.31302	validation_1-error:0.11774	validation_1-logloss:0.33135
# [7]	validation_0-error:0.09194	validation_0-logloss:0.29977	validation_1-error:0.11208	validation_1-logloss:0.31756
# [8]	validation_0-error:0.09117	validation_0-logloss:0.29172	validation_1-error:0.11003	validation_1-logloss:0.30916
# [9]	validation_0-error:0.08718	validation_0-logloss:0.27966	validation_1-error:0.10591	validation_1-logloss:0.29897
# [10]	validation_0-error:0.08602	validation_0-logloss:0.26899	validation_1-error:0.10180	validation_1-logloss:0.28944
# [11]	validation_0-error:0.08512	validation_0-logloss:0.26206	validation_1-error:0.10180	validation_1-logloss:0.28391
# [12]	validation_0-error:0.08409	validation_0-logloss:0.25850	validation_1-error:0.10077	validation_1-logloss:0.28167
# [13]	validation_0-error:0.08281	validation_0-logloss:0.24877	validation_1-error:0.10026	validation_1-logloss:0.27305
# [14]	validation_0-error:0.08101	validation_0-logloss:0.24336	validation_1-error:0.09769	validation_1-logloss:0.26790
# [15]	validation_0-error:0.07792	validation_0-logloss:0.23780	validation_1-error:0.09563	validation_1-logloss:0.26450
# [16]	validation_0-error:0.07278	validation_0-logloss:0.22842	validation_1-error:0.09254	validation_1-logloss:0.25613
# [17]	validation_0-error:0.06725	validation_0-logloss:0.21987	validation_1-error:0.09049	validation_1-logloss:0.24851
# [18]	validation_0-error:0.06223	validation_0-logloss:0.20860	validation_1-error:0.08380	validation_1-logloss:0.23742
# [19]	validation_0-error:0.05478	validation_0-logloss:0.19775	validation_1-error:0.07661	validation_1-logloss:0.22763
# [20]	validation_0-error:0.05182	validation_0-logloss:0.19181	validation_1-error:0.07404	validation_1-logloss:0.22270
# [21]	validation_0-error:0.05105	validation_0-logloss:0.18734	validation_1-error:0.07198	validation_1-logloss:0.21883
# [22]	validation_0-error:0.04629	validation_0-logloss:0.17658	validation_1-error:0.06889	validation_1-logloss:0.20897
# [23]	validation_0-error:0.04359	validation_0-logloss:0.17165	validation_1-error:0.06478	validation_1-logloss:0.20551
# [24]	validation_0-error:0.04346	validation_0-logloss:0.17031	validation_1-error:0.06478	validation_1-logloss:0.20422
# [25]	validation_0-error:0.04256	validation_0-logloss:0.16809	validation_1-error:0.06375	validation_1-logloss:0.20228
# [26]	validation_0-error:0.04140	validation_0-logloss:0.16370	validation_1-error:0.06221	validation_1-logloss:0.19848
# [27]	validation_0-error:0.04128	validation_0-logloss:0.16254	validation_1-error:0.06272	validation_1-logloss:0.19717
# [28]	validation_0-error:0.04063	validation_0-logloss:0.15934	validation_1-error:0.06170	validation_1-logloss:0.19403
# [29]	validation_0-error:0.03870	validation_0-logloss:0.15577	validation_1-error:0.06221	validation_1-logloss:0.19057
# [30]	validation_0-error:0.03819	validation_0-logloss:0.15082	validation_1-error:0.06221	validation_1-logloss:0.18674
# [31]	validation_0-error:0.03562	validation_0-logloss:0.14593	validation_1-error:0.06118	validation_1-logloss:0.18191
# [32]	validation_0-error:0.03305	validation_0-logloss:0.14311	validation_1-error:0.05810	validation_1-logloss:0.17853
# [33]	validation_0-error:0.03176	validation_0-logloss:0.13774	validation_1-error:0.05758	validation_1-logloss:0.17499
# [34]	validation_0-error:0.03060	validation_0-logloss:0.13380	validation_1-error:0.05553	validation_1-logloss:0.17167
# [35]	validation_0-error:0.02945	validation_0-logloss:0.12984	validation_1-error:0.05501	validation_1-logloss:0.16677
# [36]	validation_0-error:0.02893	validation_0-logloss:0.12765	validation_1-error:0.05450	validation_1-logloss:0.16428
# [37]	validation_0-error:0.02713	validation_0-logloss:0.12380	validation_1-error:0.05398	validation_1-logloss:0.16105
# [38]	validation_0-error:0.02572	validation_0-logloss:0.12161	validation_1-error:0.04987	validation_1-logloss:0.15887
# [39]	validation_0-error:0.02572	validation_0-logloss:0.11651	validation_1-error:0.05347	validation_1-logloss:0.15504
# [40]	validation_0-error:0.02533	validation_0-logloss:0.11423	validation_1-error:0.05296	validation_1-logloss:0.15286
# [41]	validation_0-error:0.02495	validation_0-logloss:0.11345	validation_1-error:0.05244	validation_1-logloss:0.15213
# [42]	validation_0-error:0.02379	validation_0-logloss:0.11234	validation_1-error:0.05244	validation_1-logloss:0.15057
# [43]	validation_0-error:0.02353	validation_0-logloss:0.11130	validation_1-error:0.05244	validation_1-logloss:0.15004
# [44]	validation_0-error:0.02225	validation_0-logloss:0.10925	validation_1-error:0.05193	validation_1-logloss:0.14918
# [45]	validation_0-error:0.02186	validation_0-logloss:0.10876	validation_1-error:0.05193	validation_1-logloss:0.14861
# [46]	validation_0-error:0.02186	validation_0-logloss:0.10691	validation_1-error:0.05141	validation_1-logloss:0.14735
# [47]	validation_0-error:0.02147	validation_0-logloss:0.10516	validation_1-error:0.05141	validation_1-logloss:0.14683
# [48]	validation_0-error:0.01954	validation_0-logloss:0.10137	validation_1-error:0.04781	validation_1-logloss:0.14324
# [49]	validation_0-error:0.01942	validation_0-logloss:0.10054	validation_1-error:0.04730	validation_1-logloss:0.14241
# [50]	validation_0-error:0.01852	validation_0-logloss:0.09616	validation_1-error:0.04524	validation_1-logloss:0.13872
# [51]	validation_0-error:0.01839	validation_0-logloss:0.09535	validation_1-error:0.04524	validation_1-logloss:0.13797
# [52]	validation_0-error:0.01774	validation_0-logloss:0.09395	validation_1-error:0.04524	validation_1-logloss:0.13747
# [53]	validation_0-error:0.01736	validation_0-logloss:0.09285	validation_1-error:0.04524	validation_1-logloss:0.13676
# [54]	validation_0-error:0.01697	validation_0-logloss:0.09205	validation_1-error:0.04370	validation_1-logloss:0.13606
# [55]	validation_0-error:0.01646	validation_0-logloss:0.08923	validation_1-error:0.04370	validation_1-logloss:0.13379
# [56]	validation_0-error:0.01633	validation_0-logloss:0.08807	validation_1-error:0.04165	validation_1-logloss:0.13286
# [57]	validation_0-error:0.01530	validation_0-logloss:0.08537	validation_1-error:0.04010	validation_1-logloss:0.13042
# [58]	validation_0-error:0.01440	validation_0-logloss:0.08315	validation_1-error:0.04062	validation_1-logloss:0.12842
# [59]	validation_0-error:0.01389	validation_0-logloss:0.08105	validation_1-error:0.04010	validation_1-logloss:0.12687
# [60]	validation_0-error:0.01389	validation_0-logloss:0.08035	validation_1-error:0.04010	validation_1-logloss:0.12609
# [61]	validation_0-error:0.01324	validation_0-logloss:0.07748	validation_1-error:0.03856	validation_1-logloss:0.12316
# [62]	validation_0-error:0.01324	validation_0-logloss:0.07666	validation_1-error:0.03805	validation_1-logloss:0.12225
# [63]	validation_0-error:0.01273	validation_0-logloss:0.07524	validation_1-error:0.03907	validation_1-logloss:0.12106
# [64]	validation_0-error:0.01222	validation_0-logloss:0.07331	validation_1-error:0.03856	validation_1-logloss:0.12000
# [65]	validation_0-error:0.01144	validation_0-logloss:0.07118	validation_1-error:0.03856	validation_1-logloss:0.11861
# [66]	validation_0-error:0.01080	validation_0-logloss:0.06897	validation_1-error:0.03805	validation_1-logloss:0.11693
# [67]	validation_0-error:0.01054	validation_0-logloss:0.06848	validation_1-error:0.03805	validation_1-logloss:0.11696
# [68]	validation_0-error:0.01003	validation_0-logloss:0.06763	validation_1-error:0.03650	validation_1-logloss:0.11640
# [69]	validation_0-error:0.00939	validation_0-logloss:0.06576	validation_1-error:0.03599	validation_1-logloss:0.11379
# [70]	validation_0-error:0.00874	validation_0-logloss:0.06424	validation_1-error:0.03496	validation_1-logloss:0.11188
# [71]	validation_0-error:0.00849	validation_0-logloss:0.06240	validation_1-error:0.03445	validation_1-logloss:0.11059
# [72]	validation_0-error:0.00823	validation_0-logloss:0.06180	validation_1-error:0.03393	validation_1-logloss:0.11011
# [73]	validation_0-error:0.00797	validation_0-logloss:0.05967	validation_1-error:0.03342	validation_1-logloss:0.10779
# [74]	validation_0-error:0.00733	validation_0-logloss:0.05792	validation_1-error:0.03342	validation_1-logloss:0.10613
# [75]	validation_0-error:0.00733	validation_0-logloss:0.05753	validation_1-error:0.03342	validation_1-logloss:0.10548
# [76]	validation_0-error:0.00720	validation_0-logloss:0.05636	validation_1-error:0.03342	validation_1-logloss:0.10434
# [77]	validation_0-error:0.00656	validation_0-logloss:0.05548	validation_1-error:0.03342	validation_1-logloss:0.10354
# [78]	validation_0-error:0.00630	validation_0-logloss:0.05398	validation_1-error:0.03290	validation_1-logloss:0.10216
# [79]	validation_0-error:0.00591	validation_0-logloss:0.05258	validation_1-error:0.03239	validation_1-logloss:0.10067
# [80]	validation_0-error:0.00566	validation_0-logloss:0.05190	validation_1-error:0.03239	validation_1-logloss:0.10004
# [81]	validation_0-error:0.00540	validation_0-logloss:0.05089	validation_1-error:0.03188	validation_1-logloss:0.09946
# [82]	validation_0-error:0.00540	validation_0-logloss:0.04966	validation_1-error:0.03136	validation_1-logloss:0.09815
# [83]	validation_0-error:0.00514	validation_0-logloss:0.04913	validation_1-error:0.03136	validation_1-logloss:0.09751
# [84]	validation_0-error:0.00514	validation_0-logloss:0.04828	validation_1-error:0.03188	validation_1-logloss:0.09690
# [85]	validation_0-error:0.00450	validation_0-logloss:0.04610	validation_1-error:0.03085	validation_1-logloss:0.09528
# [86]	validation_0-error:0.00411	validation_0-logloss:0.04504	validation_1-error:0.03136	validation_1-logloss:0.09447
# [87]	validation_0-error:0.00399	validation_0-logloss:0.04455	validation_1-error:0.03085	validation_1-logloss:0.09405
# [88]	validation_0-error:0.00347	validation_0-logloss:0.04305	validation_1-error:0.03085	validation_1-logloss:0.09275
# [89]	validation_0-error:0.00347	validation_0-logloss:0.04233	validation_1-error:0.03085	validation_1-logloss:0.09193
# [90]	validation_0-error:0.00347	validation_0-logloss:0.04160	validation_1-error:0.03085	validation_1-logloss:0.09089
# [91]	validation_0-error:0.00309	validation_0-logloss:0.04050	validation_1-error:0.02982	validation_1-logloss:0.08990
# [92]	validation_0-error:0.00296	validation_0-logloss:0.04026	validation_1-error:0.02982	validation_1-logloss:0.08965
# [93]	validation_0-error:0.00270	validation_0-logloss:0.03933	validation_1-error:0.02931	validation_1-logloss:0.08927
# [94]	validation_0-error:0.00270	validation_0-logloss:0.03857	validation_1-error:0.02879	validation_1-logloss:0.08840
# [95]	validation_0-error:0.00270	validation_0-logloss:0.03775	validation_1-error:0.02982	validation_1-logloss:0.08739
# [96]	validation_0-error:0.00231	validation_0-logloss:0.03657	validation_1-error:0.02931	validation_1-logloss:0.08638
# [97]	validation_0-error:0.00231	validation_0-logloss:0.03602	validation_1-error:0.02931	validation_1-logloss:0.08563
# [98]	validation_0-error:0.00219	validation_0-logloss:0.03538	validation_1-error:0.02931	validation_1-logloss:0.08515
# [99]	validation_0-error:0.00219	validation_0-logloss:0.03504	validation_1-error:0.02931	validation_1-logloss:0.08489

# %%
model = XGBClassifier(eval_metric="logloss",early_stopping_rounds=10)
eval_set = [(x_test, y_test)]
model.fit(x_train,y_train, eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-logloss:0.56337
# [1]	validation_0-logloss:0.48586
# [2]	validation_0-logloss:0.43022
# [3]	validation_0-logloss:0.39625
# [4]	validation_0-logloss:0.36730
# [5]	validation_0-logloss:0.35037
# [6]	validation_0-logloss:0.33135
# [7]	validation_0-logloss:0.31756
# [8]	validation_0-logloss:0.30916
# [9]	validation_0-logloss:0.29897
# [10]	validation_0-logloss:0.28944
# [11]	validation_0-logloss:0.28391
# [12]	validation_0-logloss:0.28167
# [13]	validation_0-logloss:0.27305
# [14]	validation_0-logloss:0.26790
# [15]	validation_0-logloss:0.26450
# [16]	validation_0-logloss:0.25613
# [17]	validation_0-logloss:0.24851
# [18]	validation_0-logloss:0.23742
# [19]	validation_0-logloss:0.22763
# [20]	validation_0-logloss:0.22270
# [21]	validation_0-logloss:0.21883
# [22]	validation_0-logloss:0.20897
# [23]	validation_0-logloss:0.20551
# [24]	validation_0-logloss:0.20422
# [25]	validation_0-logloss:0.20228
# [26]	validation_0-logloss:0.19848
# [27]	validation_0-logloss:0.19717
# [28]	validation_0-logloss:0.19403
# [29]	validation_0-logloss:0.19057
# [30]	validation_0-logloss:0.18674
# [31]	validation_0-logloss:0.18191
# [32]	validation_0-logloss:0.17853
# [33]	validation_0-logloss:0.17499
# [34]	validation_0-logloss:0.17167
# [35]	validation_0-logloss:0.16677
# [36]	validation_0-logloss:0.16428
# [37]	validation_0-logloss:0.16105
# [38]	validation_0-logloss:0.15887
# [39]	validation_0-logloss:0.15504
# [40]	validation_0-logloss:0.15286
# [41]	validation_0-logloss:0.15213
# [42]	validation_0-logloss:0.15057
# [43]	validation_0-logloss:0.15004
# [44]	validation_0-logloss:0.14918
# [45]	validation_0-logloss:0.14861
# [46]	validation_0-logloss:0.14735
# [47]	validation_0-logloss:0.14683
# [48]	validation_0-logloss:0.14324
# [49]	validation_0-logloss:0.14241
# [50]	validation_0-logloss:0.13872
# [51]	validation_0-logloss:0.13797
# [52]	validation_0-logloss:0.13747
# [53]	validation_0-logloss:0.13676
# [54]	validation_0-logloss:0.13606
# [55]	validation_0-logloss:0.13379
# [56]	validation_0-logloss:0.13286
# [57]	validation_0-logloss:0.13042
# [58]	validation_0-logloss:0.12842
# [59]	validation_0-logloss:0.12687
# [60]	validation_0-logloss:0.12609
# [61]	validation_0-logloss:0.12316
# [62]	validation_0-logloss:0.12225
# [63]	validation_0-logloss:0.12106
# [64]	validation_0-logloss:0.12000
# [65]	validation_0-logloss:0.11861
# [66]	validation_0-logloss:0.11693
# [67]	validation_0-logloss:0.11696
# [68]	validation_0-logloss:0.11640
# [69]	validation_0-logloss:0.11379
# [70]	validation_0-logloss:0.11188
# [71]	validation_0-logloss:0.11059
# [72]	validation_0-logloss:0.11011
# [73]	validation_0-logloss:0.10779
# [74]	validation_0-logloss:0.10613
# [75]	validation_0-logloss:0.10548
# [76]	validation_0-logloss:0.10434
# [77]	validation_0-logloss:0.10354
# [78]	validation_0-logloss:0.10216
# [79]	validation_0-logloss:0.10067
# [80]	validation_0-logloss:0.10004
# [81]	validation_0-logloss:0.09946
# [82]	validation_0-logloss:0.09815
# [83]	validation_0-logloss:0.09751
# [84]	validation_0-logloss:0.09690
# [85]	validation_0-logloss:0.09528
# [86]	validation_0-logloss:0.09447
# [87]	validation_0-logloss:0.09405
# [88]	validation_0-logloss:0.09275
# [89]	validation_0-logloss:0.09193
# [90]	validation_0-logloss:0.09089
# [91]	validation_0-logloss:0.08990
# [92]	validation_0-logloss:0.08965
# [93]	validation_0-logloss:0.08927
# [94]	validation_0-logloss:0.08840
# [95]	validation_0-logloss:0.08739
# [96]	validation_0-logloss:0.08638
# [97]	validation_0-logloss:0.08563
# [98]	validation_0-logloss:0.08515
# [99]	validation_0-logloss:0.08489
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from xgboost import plot_importance

# %%
plot_importance(model,importance_type='cover')
plt.title("Feature importance by cover")
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
y_pred = lr.predict(x_test)
print("Classification report - \n",classification_report(y_test,y_pred))
# Out:
# Classification report -
#                precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76       988
#            1       0.75      0.79      0.77       957
#
#     accuracy                           0.77      1945
#    macro avg       0.77      0.77      0.77      1945
# weighted avg       0.77      0.77      0.77      1945

# %%
cm = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(5,5))
sns.heatmap(data=cm,linewidths=5, annot=True,square=True,cmap='Blues')
plt.xlabel("Predicted label")
plt.ylabel("Actual label")
all_sample_title = 'Accuracy Score: {0}'.format(lr.score(x_test,y_test)*100)
plt.title(all_sample_title,size = 15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 76.60668380462725')

# %%
from sklearn.metrics import roc_curve,roc_auc_score
y_pred_proba = lr.predict_proba(x_test)[:][:,1]
df_actual_predicted  = pd.concat([pd.DataFrame(np.array(y_test),columns=["y_actual"]),pd.DataFrame(y_pred_proba,columns=['y_pred_proba'])],axis=1)
df_actual_predicted.index = y_test.index
fpr,tpr,tr = roc_curve(df_actual_predicted['y_actual'],df_actual_predicted['y_pred_proba'])
auc = roc_auc_score(df_actual_predicted['y_actual'],df_actual_predicted['y_pred_proba'])
plt.plot(fpr,tpr,label='AUC = %0.4f' % float(auc))
plt.plot(fpr,fpr,linestyle='--',color='k')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC Curve",size=15)
plt.legend()

# %%
y_pred_prob = lr.predict_proba(x_test)[0:10]
y_pred_prob_df = pd.DataFrame(data = y_pred_prob*100,columns=['Prob. of dont have Stroke','Prob. of having Stroke']).round(2)
y_pred_prob_df
# Out:
#    Prob. of dont have Stroke  Prob. of having Stroke
# 0                      62.66                   37.34
# 1                      89.78                   10.22
# 2                      14.74                   85.26
# 3                      45.55                   54.45
# 4                      97.36                    2.64
# 5                      67.98                   32.02
# 6                      44.07                   55.93
# 7                      36.75                   63.25
# 8                      46.95                   53.05
# 9                      86.84                   13.16

# %%
y_pred1 = lr.predict_proba(x_test)[:,1]
sns.kdeplot(y_pred1, shade=True, color="purple")
plt.title('KDE Plot of Predicted Stroke Probabilities')
plt.xlabel('Predicted Probability of Stroke')
plt.ylabel('Density')
plt.xlim(0, 1)
plt.grid(True)
plt.show()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_23112\447361539.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_pred1, shade=True, color="purple")

# %% [markdown]
# # Predicting Stroke by Inputing Number

# %%
Xnew = [[1, 50, 0, 1, 0, 3, 1, 140, 25, 2]]
y_pred_prob2 = lr.predict_proba(Xnew)
y_pred_prob_df2 = pd.DataFrame(data=y_pred_prob2, columns=['Prob of dont have stroke', 'Prob of have stroke'])
y_pred_prob_df2
# Out:
# C:\Users\priya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
#    Prob of dont have stroke  Prob of have stroke
# 0                  0.400265             0.599735

# %% [markdown]
# # Random Forest

# %%
y_pred = rfc.predict(x_test)
print('Classification Report- \n',classification_report(y_test,y_pred))
# Out:
# Classification Report-
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       988
#            1       0.98      1.00      0.99       957
#
#     accuracy                           0.99      1945
#    macro avg       0.99      0.99      0.99      1945
# weighted avg       0.99      0.99      0.99      1945

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(data=cm,linewidths=5,annot=True,square=True,cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
all_sample_title = 'Accuracy Score {0}'.format(rfc.score(x_test,y_test)*100)
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score 99.02313624678663')

# %%
# already imported roc_curve,roc_auc_score
y_pred_prob = rfc.predict_proba(x_test)[:][:,1]
df_actual_predicted = pd.concat([pd.DataFrame(np.array(y_test),columns=["y_actual"]),pd.DataFrame(np.array(y_pred_prob),columns=['y_pred_prob'])],axis=1)
df_actual_predicted.index = y_test.index
fpr,tpr,tr = roc_curve(df_actual_predicted['y_actual'],df_actual_predicted['y_pred_prob'])
auc = roc_auc_score(df_actual_predicted['y_actual'],df_actual_predicted['y_pred_prob'])
plt.plot(fpr,tpr, label='AUC %0.4f' %auc)
plt.plot(fpr,fpr,linestyle='--',color='k')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC Curve",size=15)
plt.legend()

# %%
# Feature Importance
imp_df = pd.DataFrame({
    'Feature Name': x_train.columns,
    'Importance': rfc.feature_importances_
})
imp_df.sort_values(by='Importance',ascending=False)
# Out:
#         Feature Name  Importance
# 1                age    0.401780
# 7  avg_glucose_level    0.197917
# 8                bmi    0.181433
# 9     smoking_status    0.053218
# 5          work_type    0.043874
# 4       ever_married    0.029760
# 2       hypertension    0.028898
# 0             gender    0.022902
# 6     Residence_type    0.020907
# 3      heart_disease    0.019308

# %%
y_pred_prob = rfc.predict_proba(x_test)[0:10]
y_pred_prob_df = pd.DataFrame(data=y_pred_prob*100, columns=['Prob of dont have stroke', 'Prob of have stroke']).round(2)
y_pred_prob_df
# Out:
#    Prob of dont have stroke  Prob of have stroke
# 0                      95.0                  5.0
# 1                     100.0                  0.0
# 2                       0.0                100.0
# 3                      97.0                  3.0
# 4                     100.0                  0.0
# 5                      98.0                  2.0
# 6                      83.0                 17.0
# 7                      94.0                  6.0
# 8                       0.0                100.0
# 9                     100.0                  0.0

# %%
y_pred2 = rfc.predict_proba(x_test)[:,1]
sns.kdeplot(y_pred1, shade=True, color="purple")
plt.title('KDE Plot of Predicted Stroke Probabilities')
plt.xlabel('Predicted Probability of Stroke')
plt.ylabel('Density')
plt.xlim(0, 1)
plt.grid(True)
plt.show()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_23112\3790121370.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_pred1, shade=True, color="purple")

# %% [markdown]
# # Predicting Stroke by Inputing Number

# %%
Xnew2 = [[29,48,69,23,4,8,2,7,106,45]]
y_pred_prob3 = rfc.predict_proba(Xnew2)
y_pred_prob3_df = pd.DataFrame(data=y_pred_prob3*100,columns=['Prob. of dont have Stroke','Prob of have Stroke'])
y_pred_prob3_df
# Out:
# C:\Users\priya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
#    Prob. of dont have Stroke  Prob of have Stroke
# 0                       92.0                  8.0

# %% [markdown]
# # HYPERPARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
}

grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, scoring='accuracy')
grid.fit(x_train, y_train)
grid.best_params_
# Out:
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# # BEST SCORE AFTER TUNING IS

# %%
print("Accuracy Score is: ",(grid.best_score_*100).round(2))
# Out:
# Accuracy Score is:  98.98

# %%
gender = input("Your Gender (0=Female, 1=Male) : ")
age = input("Your Age: ")
hypertension = input("Do you have hypertension ? (0 = No, 1 = Yes) : ")
heart = input("Do you have heart disease ? (0 = No, 1 = Yes) :")
marry = input("Did you ever married ? (0 = No, 1 = Yes) :")
work = input("Your Worktype ? (0 = children, 1 = Government job, 2 = Never worked, 3 = Private, 4 = Self Employed) : ")
residence = input("Your Residence type ? (0 = Rural, 1 = Urban) : ")
avg = input("Average Glucose Level : ")
bmi = input("Your BMI : ")
smoke = input("Your Smoking status ? (0 = never smoked, 1 = formerly smoked, 2 = smokes, 3 = unknown) : ")

Xnew3 = [[gender, age, hypertension, heart, marry, work, residence, avg,bmi,smoke]]


y_pred_prob4 = grid.predict_proba(Xnew3)
y_pred_prob_df4 = pd.DataFrame(data=y_pred_prob4*100, columns=['Prob of dont have stroke', 'Prob of have stroke'])
y_pred_prob_df4
# Out:
# Your Gender (0=Female, 1=Male) :  0
# Your Age:  19
# Do you have hypertension ? (0 = No, 1 = Yes) :  0
# Do you have heart disease ? (0 = No, 1 = Yes) : 0

# %%
import joblib

# Save it
joblib.dump(rfc, 'stroke_model.pkl')

# Later or in another file/notebook
rfc_loaded = joblib.load('stroke_model.pkl')

# Predict with the loaded model
y_pred = rfc_loaded.predict(x_test)
